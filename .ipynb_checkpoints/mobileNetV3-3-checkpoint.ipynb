# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import tensorflow as tf
import random
import time
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV3Large
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, accuracy_score
from matplotlib.colors import LinearSegmentedColormap
import math
from imblearn.over_sampling import RandomOverSampler
import cv2

# %%
path = "../germany_dataset/train.csv"
df = pd.read_csv(path)
df = df.dropna()
filename="mobileNetV3"

# %%
df["length"] = df["Roi.X2"]-df["Roi.X1"]
df["height"] = df["Roi.Y2"]-df["Roi.Y1"]
df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId  \
# 0     27      26       5       5      22      20       20
# 1     28      27       5       6      23      22       20
# 2     29      26       6       5      24      21       20
# 3     28      27       5       6      23      22       20
# 4     28      26       5       5      23      21       20
#
#                              Path  length  height
# 0  Train/20/00020_00000_00000.png      17      15
# 1  Train/20/00020_00000_00001.png      18      16
# 2  Train/20/00020_00000_00002.png      18      16
# 3  Train/20/00020_00000_00003.png      18      16
# 4  Train/20/00020_00000_00004.png      18      16

# %%
df.describe()
# Out:
#               Width        Height        Roi.X1        Roi.Y1        Roi.X2  \
# count  39209.000000  39209.000000  39209.000000  39209.000000  39209.000000
# mean      50.835880     50.328930      5.999515      5.962381     45.197302
# std       24.306933     23.115423      1.475493      1.385440     23.060157
# min       25.000000     25.000000      0.000000      5.000000     20.000000
# 25%       35.000000     35.000000      5.000000      5.000000     29.000000
# 50%       43.000000     43.000000      6.000000      6.000000     38.000000
# 75%       58.000000     58.000000      6.000000      6.000000     53.000000
# max      243.000000    225.000000     20.000000     20.000000    223.000000
#
#              Roi.Y2       ClassId        length        height
# count  39209.000000  39209.000000  39209.000000  39209.000000
# mean      44.728379     15.788390     39.197786     38.765998
# std       21.971145     12.013238     21.821369     20.828697
# min       20.000000      0.000000     15.000000     15.000000
# 25%       30.000000      5.000000     24.000000     24.000000
# 50%       38.000000     12.000000     33.000000     32.000000
# 75%       52.000000     25.000000     47.000000     47.000000
# max      205.000000     42.000000    203.000000    185.000000

# %%
# All Variables declaration to use same code for different datasets
num_of_classes = df["ClassId"].nunique()
resize_x  = 32
resize_y  = 32
num_of_channels = 3
directory = "../germany_dataset/"
testdir = "../germany_dataset/test.csv"
Epochs=100
train_length = len(df)
Y_col_name="ClassId"

# %%
# Necessary Functions
def remove_outlier(df,parameter):
    Percentile25 = df[parameter].quantile(0.25)
    Percentile75 = df[parameter].quantile(0.75)
    iqr = Percentile75 - Percentile25
    lowerlimit = Percentile25 - 1.5*iqr
    upperlimit = Percentile75 + 1.5*iqr
    temp1 = df[parameter]>lowerlimit
    temp2 = df[parameter]<upperlimit
    return df[temp1 & temp2] 

def get_max_index(arr):
    length = len(arr)
    mini = 0
    value = 0
    for i,val in enumerate(arr):
        if mini < val :
            mini = val
            value = i
    return value

def viewStatistics(df):
    #Statistics of Data
    print("Total Training Examples : ",len(df))
    values = df["ClassId"].value_counts()
    x_labels = [str(x) for x in range(num_of_classes)]
    y_labels = []
    for x in range(num_of_classes):
        y_labels.append(values[x])
    plt.figure(figsize=(15, 6))
    plt.bar(x_labels,y_labels,width=0.5)
    plt.title('Bar Graph')
    plt.xlabel('Class')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

def Predict_for_single_example(model,img):
    img  = np.array(img)
    img  = tf.convert_to_tensor(img,dtype=float)
    img = img/255.0
    img = tf.expand_dims(img, axis=0)
    probability = model.predict(img)
    value = get_max_index(probability[0])
    return value
    
def Predict_for_Multiple_examples(model,images):
    img = []
    for j in range(len(images)):
        img.append(np.array(images[j]))
    img = np.array(img)
    img = tf.convert_to_tensor(img,dtype=float)
    img = img/255.0
    probability = model.predict(img)
    values = []
    for val in probability:
        values.append(get_max_index(val))
    return values

def PredictTest(model,df,start,length):
    images = []
    y_test = []
    length = min(length,len(df)-start)
    for i in range(length):
        row = df.loc[start+i].values
        images.append(Image.open(directory+row[7]).crop((row[2],row[3],row[4],row[5])).resize((resize_x,resize_y)))
        y_test.append(row[6])
    

    y_predicted = Predict_for_Multiple_examples(model,images)

    return y_test,y_predicted

def PredictTest(model,df):
    images = []
    y_test = []
    length = len(df)
    for i in range(length):
        row = df.loc[i].values
        images.append(Image.open(directory+row[7]).crop((row[2],row[3],row[4],row[5])).resize((resize_x,resize_y)))
        y_test.append(row[6])
        
    y_predicted = Predict_for_Multiple_examples(model,images)

    return y_test,y_predicted

# %%
#Statistics of Data
viewStatistics(df)
# Out:
# Total Training Examples :  39209

# %%
train_length = len(df)
print("Total Training Examples : ",len(df))
# Out:
# Total Training Examples :  39209

# %%
X = df.drop(Y_col_name, axis=1)
y = df[Y_col_name]
oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)

# Fit and apply the oversampler to the data
X_resampled, y_resampled = oversampler.fit_resample(X, y)

df = pd.DataFrame(X_resampled, columns=X.columns)
df[Y_col_name] = y_resampled
df[Y_col_name].astype(str)

viewStatistics(df)
# Out:
# Total Training Examples :  96750

# %%
df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  \
# 0     27      26       5       5      22      20
# 1     28      27       5       6      23      22
# 2     29      26       6       5      24      21
# 3     28      27       5       6      23      22
# 4     28      26       5       5      23      21
#
#                              Path  length  height  ClassId
# 0  Train/20/00020_00000_00000.png      17      15       20
# 1  Train/20/00020_00000_00001.png      18      16       20
# 2  Train/20/00020_00000_00002.png      18      16       20
# 3  Train/20/00020_00000_00003.png      18      16       20
# 4  Train/20/00020_00000_00004.png      18      16       20

# %%
# Sample Images and there crop according to data given in csv
def showExamples(df):
    num_rows = 5
    num_cols = 2
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 20))
    total_images = []
    for i in range(5):
        integer = random.randint(0,len(df))
        total_images.append(df.iloc[integer].values)
    total_images = list(total_images)
    for i,val in enumerate(total_images):
        row = i
        col=0
        ax = axes[row, col]
        img = Image.open(directory+val[6])
        ax.imshow(img)
        img = img.crop((val[2],val[3],val[4],val[5]))
        ax = axes[row,col+1]
        ax.imshow(img)
        ax.set_title(directory+val[6])
        print(directory+val[6])
    ax.axis('off')

def showTestExamples(df):
    num_rows = 5
    num_cols = 2
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 20))
    total_images = []
    for i in range(5):
        integer = random.randint(0,len(df))
        total_images.append(df.iloc[integer].values)
    total_images = list(total_images)
    for i,val in enumerate(total_images):
        row = i
        col=0
        ax = axes[row, col]
        img = Image.open(directory+val[7])
        ax.imshow(img)
        img = img.crop((val[2],val[3],val[4],val[5]))
        ax = axes[row,col+1]
        ax.imshow(img)
        ax.set_title("Class : "+str(val[6]))
    ax.axis('off')

# %%
showExamples(df)
# Out:
# ../germany_dataset/Train/22/00022_00001_00022.png
# ../germany_dataset/Train/1/00001_00046_00002.png
# ../germany_dataset/Train/38/00038_00013_00023.png
# ../germany_dataset/Train/32/00032_00004_00008.png
# ../germany_dataset/Train/4/00004_00028_00010.png

# %%
model = MobileNetV3Large(weights=None, input_shape=(resize_x, resize_y, 3), classes=num_of_classes)

# Display the model summary
model.summary()
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]          0         []
#
#  rescaling_1 (Rescaling)     (None, 32, 32, 3)            0         ['input_2[0][0]']
#
#  Conv (Conv2D)               (None, 16, 16, 16)           432       ['rescaling_1[0][0]']
#
#  Conv/BatchNorm (BatchNorma  (None, 16, 16, 16)           64        ['Conv[0][0]']
#  lization)
#
#  tf.__operators__.add_29 (T  (None, 16, 16, 16)           0         ['Conv/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_40 (ReLU)             (None, 16, 16, 16)           0         ['tf.__operators__.add_29[0][0
#                                                                     ]']
#
#  tf.math.multiply_29 (TFOpL  (None, 16, 16, 16)           0         ['re_lu_40[0][0]']
#  ambda)
#
#  multiply_21 (Multiply)      (None, 16, 16, 16)           0         ['Conv/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_29[0][0]']
#
#  expanded_conv/depthwise (D  (None, 16, 16, 16)           144       ['multiply_21[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv/depthwise/Ba  (None, 16, 16, 16)           64        ['expanded_conv/depthwise[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  re_lu_41 (ReLU)             (None, 16, 16, 16)           0         ['expanded_conv/depthwise/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv/project (Con  (None, 16, 16, 16)           256       ['re_lu_41[0][0]']
#  v2D)
#
#  expanded_conv/project/Batc  (None, 16, 16, 16)           64        ['expanded_conv/project[0][0]'
#  hNorm (BatchNormalization)                                         ]
#
#  expanded_conv/Add (Add)     (None, 16, 16, 16)           0         ['multiply_21[0][0]',
#                                                                      'expanded_conv/project/BatchN
#                                                                     orm[0][0]']
#
#  expanded_conv_1/expand (Co  (None, 16, 16, 64)           1024      ['expanded_conv/Add[0][0]']
#  nv2D)
#
#  expanded_conv_1/expand/Bat  (None, 16, 16, 64)           256       ['expanded_conv_1/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_42 (ReLU)             (None, 16, 16, 64)           0         ['expanded_conv_1/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 17, 17, 64)           0         ['re_lu_42[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_1/depthwise   (None, 8, 8, 64)             576       ['expanded_conv_1/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_1/depthwise/  (None, 8, 8, 64)             256       ['expanded_conv_1/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_43 (ReLU)             (None, 8, 8, 64)             0         ['expanded_conv_1/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_1/project (C  (None, 8, 8, 24)             1536      ['re_lu_43[0][0]']
#  onv2D)
#
#  expanded_conv_1/project/Ba  (None, 8, 8, 24)             96        ['expanded_conv_1/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/expand (Co  (None, 8, 8, 72)             1728      ['expanded_conv_1/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_2/expand/Bat  (None, 8, 8, 72)             288       ['expanded_conv_2/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_44 (ReLU)             (None, 8, 8, 72)             0         ['expanded_conv_2/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_2/depthwise   (None, 8, 8, 72)             648       ['re_lu_44[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_2/depthwise/  (None, 8, 8, 72)             288       ['expanded_conv_2/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_45 (ReLU)             (None, 8, 8, 72)             0         ['expanded_conv_2/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_2/project (C  (None, 8, 8, 24)             1728      ['re_lu_45[0][0]']
#  onv2D)
#
#  expanded_conv_2/project/Ba  (None, 8, 8, 24)             96        ['expanded_conv_2/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_2/Add (Add)   (None, 8, 8, 24)             0         ['expanded_conv_1/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_2/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_3/expand (Co  (None, 8, 8, 72)             1728      ['expanded_conv_2/Add[0][0]']
#  nv2D)
#
#  expanded_conv_3/expand/Bat  (None, 8, 8, 72)             288       ['expanded_conv_3/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_46 (ReLU)             (None, 8, 8, 72)             0         ['expanded_conv_3/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 11, 11, 72)           0         ['re_lu_46[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_3/depthwise   (None, 4, 4, 72)             1800      ['expanded_conv_3/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_3/depthwise/  (None, 4, 4, 72)             288       ['expanded_conv_3/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_47 (ReLU)             (None, 4, 4, 72)             0         ['expanded_conv_3/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             0         ['re_lu_47[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             1752      ['expanded_conv_3/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 24)             0         ['expanded_conv_3/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_3/squeeze_ex  (None, 1, 1, 72)             1800      ['expanded_conv_3/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_30 (T  (None, 1, 1, 72)             0         ['expanded_conv_3/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_48 (ReLU)             (None, 1, 1, 72)             0         ['tf.__operators__.add_30[0][0
#                                                                     ]']
#
#  tf.math.multiply_30 (TFOpL  (None, 1, 1, 72)             0         ['re_lu_48[0][0]']
#  ambda)
#
#  expanded_conv_3/squeeze_ex  (None, 4, 4, 72)             0         ['re_lu_47[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_30[0][0]']
#
#  expanded_conv_3/project (C  (None, 4, 4, 40)             2880      ['expanded_conv_3/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_3/project/Ba  (None, 4, 4, 40)             160       ['expanded_conv_3/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/expand (Co  (None, 4, 4, 120)            4800      ['expanded_conv_3/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_4/expand/Bat  (None, 4, 4, 120)            480       ['expanded_conv_4/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_49 (ReLU)             (None, 4, 4, 120)            0         ['expanded_conv_4/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_4/depthwise   (None, 4, 4, 120)            3000      ['re_lu_49[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_4/depthwise/  (None, 4, 4, 120)            480       ['expanded_conv_4/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_50 (ReLU)             (None, 4, 4, 120)            0         ['expanded_conv_4/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_50[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_4/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_4/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_4/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_4/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_31 (T  (None, 1, 1, 120)            0         ['expanded_conv_4/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_51 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_31[0][0
#                                                                     ]']
#
#  tf.math.multiply_31 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_51[0][0]']
#  ambda)
#
#  expanded_conv_4/squeeze_ex  (None, 4, 4, 120)            0         ['re_lu_50[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_31[0][0]']
#
#  expanded_conv_4/project (C  (None, 4, 4, 40)             4800      ['expanded_conv_4/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_4/project/Ba  (None, 4, 4, 40)             160       ['expanded_conv_4/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_4/Add (Add)   (None, 4, 4, 40)             0         ['expanded_conv_3/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_4/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_5/expand (Co  (None, 4, 4, 120)            4800      ['expanded_conv_4/Add[0][0]']
#  nv2D)
#
#  expanded_conv_5/expand/Bat  (None, 4, 4, 120)            480       ['expanded_conv_5/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  re_lu_52 (ReLU)             (None, 4, 4, 120)            0         ['expanded_conv_5/expand/Batch
#                                                                     Norm[0][0]']
#
#  expanded_conv_5/depthwise   (None, 4, 4, 120)            3000      ['re_lu_52[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_5/depthwise/  (None, 4, 4, 120)            480       ['expanded_conv_5/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  re_lu_53 (ReLU)             (None, 4, 4, 120)            0         ['expanded_conv_5/depthwise/Ba
#                                                                     tchNorm[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            0         ['re_lu_53[0][0]']
#  cite/AvgPool (GlobalAverag
#  ePooling2D)
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             3872      ['expanded_conv_5/squeeze_exci
#  cite/Conv (Conv2D)                                                 te/AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 32)             0         ['expanded_conv_5/squeeze_exci
#  cite/Relu (ReLU)                                                   te/Conv[0][0]']
#
#  expanded_conv_5/squeeze_ex  (None, 1, 1, 120)            3960      ['expanded_conv_5/squeeze_exci
#  cite/Conv_1 (Conv2D)                                               te/Relu[0][0]']
#
#  tf.__operators__.add_32 (T  (None, 1, 1, 120)            0         ['expanded_conv_5/squeeze_exci
#  FOpLambda)                                                         te/Conv_1[0][0]']
#
#  re_lu_54 (ReLU)             (None, 1, 1, 120)            0         ['tf.__operators__.add_32[0][0
#                                                                     ]']
#
#  tf.math.multiply_32 (TFOpL  (None, 1, 1, 120)            0         ['re_lu_54[0][0]']
#  ambda)
#
#  expanded_conv_5/squeeze_ex  (None, 4, 4, 120)            0         ['re_lu_53[0][0]',
#  cite/Mul (Multiply)                                                 'tf.math.multiply_32[0][0]']
#
#  expanded_conv_5/project (C  (None, 4, 4, 40)             4800      ['expanded_conv_5/squeeze_exci
#  onv2D)                                                             te/Mul[0][0]']
#
#  expanded_conv_5/project/Ba  (None, 4, 4, 40)             160       ['expanded_conv_5/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_5/Add (Add)   (None, 4, 4, 40)             0         ['expanded_conv_4/Add[0][0]',
#                                                                      'expanded_conv_5/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_6/expand (Co  (None, 4, 4, 240)            9600      ['expanded_conv_5/Add[0][0]']
#  nv2D)
#
#  expanded_conv_6/expand/Bat  (None, 4, 4, 240)            960       ['expanded_conv_6/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_33 (T  (None, 4, 4, 240)            0         ['expanded_conv_6/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_55 (ReLU)             (None, 4, 4, 240)            0         ['tf.__operators__.add_33[0][0
#                                                                     ]']
#
#  tf.math.multiply_33 (TFOpL  (None, 4, 4, 240)            0         ['re_lu_55[0][0]']
#  ambda)
#
#  multiply_22 (Multiply)      (None, 4, 4, 240)            0         ['expanded_conv_6/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_33[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 5, 5, 240)            0         ['multiply_22[0][0]']
#  pad (ZeroPadding2D)
#
#  expanded_conv_6/depthwise   (None, 2, 2, 240)            2160      ['expanded_conv_6/depthwise/pa
#  (DepthwiseConv2D)                                                  d[0][0]']
#
#  expanded_conv_6/depthwise/  (None, 2, 2, 240)            960       ['expanded_conv_6/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_34 (T  (None, 2, 2, 240)            0         ['expanded_conv_6/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_56 (ReLU)             (None, 2, 2, 240)            0         ['tf.__operators__.add_34[0][0
#                                                                     ]']
#
#  tf.math.multiply_34 (TFOpL  (None, 2, 2, 240)            0         ['re_lu_56[0][0]']
#  ambda)
#
#  multiply_23 (Multiply)      (None, 2, 2, 240)            0         ['expanded_conv_6/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_34[0][0]']
#
#  expanded_conv_6/project (C  (None, 2, 2, 80)             19200     ['multiply_23[0][0]']
#  onv2D)
#
#  expanded_conv_6/project/Ba  (None, 2, 2, 80)             320       ['expanded_conv_6/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/expand (Co  (None, 2, 2, 200)            16000     ['expanded_conv_6/project/Batc
#  nv2D)                                                              hNorm[0][0]']
#
#  expanded_conv_7/expand/Bat  (None, 2, 2, 200)            800       ['expanded_conv_7/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_35 (T  (None, 2, 2, 200)            0         ['expanded_conv_7/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_57 (ReLU)             (None, 2, 2, 200)            0         ['tf.__operators__.add_35[0][0
#                                                                     ]']
#
#  tf.math.multiply_35 (TFOpL  (None, 2, 2, 200)            0         ['re_lu_57[0][0]']
#  ambda)
#
#  multiply_24 (Multiply)      (None, 2, 2, 200)            0         ['expanded_conv_7/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_35[0][0]']
#
#  expanded_conv_7/depthwise   (None, 2, 2, 200)            1800      ['multiply_24[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_7/depthwise/  (None, 2, 2, 200)            800       ['expanded_conv_7/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_36 (T  (None, 2, 2, 200)            0         ['expanded_conv_7/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_58 (ReLU)             (None, 2, 2, 200)            0         ['tf.__operators__.add_36[0][0
#                                                                     ]']
#
#  tf.math.multiply_36 (TFOpL  (None, 2, 2, 200)            0         ['re_lu_58[0][0]']
#  ambda)
#
#  multiply_25 (Multiply)      (None, 2, 2, 200)            0         ['expanded_conv_7/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_36[0][0]']
#
#  expanded_conv_7/project (C  (None, 2, 2, 80)             16000     ['multiply_25[0][0]']
#  onv2D)
#
#  expanded_conv_7/project/Ba  (None, 2, 2, 80)             320       ['expanded_conv_7/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_7/Add (Add)   (None, 2, 2, 80)             0         ['expanded_conv_6/project/Batc
#                                                                     hNorm[0][0]',
#                                                                      'expanded_conv_7/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_8/expand (Co  (None, 2, 2, 184)            14720     ['expanded_conv_7/Add[0][0]']
#  nv2D)
#
#  expanded_conv_8/expand/Bat  (None, 2, 2, 184)            736       ['expanded_conv_8/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_37 (T  (None, 2, 2, 184)            0         ['expanded_conv_8/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_59 (ReLU)             (None, 2, 2, 184)            0         ['tf.__operators__.add_37[0][0
#                                                                     ]']
#
#  tf.math.multiply_37 (TFOpL  (None, 2, 2, 184)            0         ['re_lu_59[0][0]']
#  ambda)
#
#  multiply_26 (Multiply)      (None, 2, 2, 184)            0         ['expanded_conv_8/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_37[0][0]']
#
#  expanded_conv_8/depthwise   (None, 2, 2, 184)            1656      ['multiply_26[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_8/depthwise/  (None, 2, 2, 184)            736       ['expanded_conv_8/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_38 (T  (None, 2, 2, 184)            0         ['expanded_conv_8/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_60 (ReLU)             (None, 2, 2, 184)            0         ['tf.__operators__.add_38[0][0
#                                                                     ]']
#
#  tf.math.multiply_38 (TFOpL  (None, 2, 2, 184)            0         ['re_lu_60[0][0]']
#  ambda)
#
#  multiply_27 (Multiply)      (None, 2, 2, 184)            0         ['expanded_conv_8/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_38[0][0]']
#
#  expanded_conv_8/project (C  (None, 2, 2, 80)             14720     ['multiply_27[0][0]']
#  onv2D)
#
#  expanded_conv_8/project/Ba  (None, 2, 2, 80)             320       ['expanded_conv_8/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_8/Add (Add)   (None, 2, 2, 80)             0         ['expanded_conv_7/Add[0][0]',
#                                                                      'expanded_conv_8/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_9/expand (Co  (None, 2, 2, 184)            14720     ['expanded_conv_8/Add[0][0]']
#  nv2D)
#
#  expanded_conv_9/expand/Bat  (None, 2, 2, 184)            736       ['expanded_conv_9/expand[0][0]
#  chNorm (BatchNormalization                                         ']
#  )
#
#  tf.__operators__.add_39 (T  (None, 2, 2, 184)            0         ['expanded_conv_9/expand/Batch
#  FOpLambda)                                                         Norm[0][0]']
#
#  re_lu_61 (ReLU)             (None, 2, 2, 184)            0         ['tf.__operators__.add_39[0][0
#                                                                     ]']
#
#  tf.math.multiply_39 (TFOpL  (None, 2, 2, 184)            0         ['re_lu_61[0][0]']
#  ambda)
#
#  multiply_28 (Multiply)      (None, 2, 2, 184)            0         ['expanded_conv_9/expand/Batch
#                                                                     Norm[0][0]',
#                                                                      'tf.math.multiply_39[0][0]']
#
#  expanded_conv_9/depthwise   (None, 2, 2, 184)            1656      ['multiply_28[0][0]']
#  (DepthwiseConv2D)
#
#  expanded_conv_9/depthwise/  (None, 2, 2, 184)            736       ['expanded_conv_9/depthwise[0]
#  BatchNorm (BatchNormalizat                                         [0]']
#  ion)
#
#  tf.__operators__.add_40 (T  (None, 2, 2, 184)            0         ['expanded_conv_9/depthwise/Ba
#  FOpLambda)                                                         tchNorm[0][0]']
#
#  re_lu_62 (ReLU)             (None, 2, 2, 184)            0         ['tf.__operators__.add_40[0][0
#                                                                     ]']
#
#  tf.math.multiply_40 (TFOpL  (None, 2, 2, 184)            0         ['re_lu_62[0][0]']
#  ambda)
#
#  multiply_29 (Multiply)      (None, 2, 2, 184)            0         ['expanded_conv_9/depthwise/Ba
#                                                                     tchNorm[0][0]',
#                                                                      'tf.math.multiply_40[0][0]']
#
#  expanded_conv_9/project (C  (None, 2, 2, 80)             14720     ['multiply_29[0][0]']
#  onv2D)
#
#  expanded_conv_9/project/Ba  (None, 2, 2, 80)             320       ['expanded_conv_9/project[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  expanded_conv_9/Add (Add)   (None, 2, 2, 80)             0         ['expanded_conv_8/Add[0][0]',
#                                                                      'expanded_conv_9/project/Batc
#                                                                     hNorm[0][0]']
#
#  expanded_conv_10/expand (C  (None, 2, 2, 480)            38400     ['expanded_conv_9/Add[0][0]']
#  onv2D)
#
#  expanded_conv_10/expand/Ba  (None, 2, 2, 480)            1920      ['expanded_conv_10/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
# ...
#                                                                      'tf.math.multiply_51[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_37[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_13/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_13/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_13/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_52 (T  (None, 1, 1, 960)            0         ['expanded_conv_13/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_74 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_52[0][0
#                                                                     ]']
#
#  tf.math.multiply_52 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_74[0][0]']
#  ambda)
#
#  expanded_conv_13/squeeze_e  (None, 1, 1, 960)            0         ['multiply_37[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_52[0][0]']
#
#  expanded_conv_13/project (  (None, 1, 1, 160)            153600    ['expanded_conv_13/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_13/project/B  (None, 1, 1, 160)            640       ['expanded_conv_13/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_13/Add (Add)  (None, 1, 1, 160)            0         ['expanded_conv_12/project/Bat
#                                                                     chNorm[0][0]',
#                                                                      'expanded_conv_13/project/Bat
#                                                                     chNorm[0][0]']
#
#  expanded_conv_14/expand (C  (None, 1, 1, 960)            153600    ['expanded_conv_13/Add[0][0]']
#  onv2D)
#
#  expanded_conv_14/expand/Ba  (None, 1, 1, 960)            3840      ['expanded_conv_14/expand[0][0
#  tchNorm (BatchNormalizatio                                         ]']
#  n)
#
#  tf.__operators__.add_53 (T  (None, 1, 1, 960)            0         ['expanded_conv_14/expand/Batc
#  FOpLambda)                                                         hNorm[0][0]']
#
#  re_lu_75 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_53[0][0
#                                                                     ]']
#
#  tf.math.multiply_53 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_75[0][0]']
#  ambda)
#
#  multiply_38 (Multiply)      (None, 1, 1, 960)            0         ['expanded_conv_14/expand/Batc
#                                                                     hNorm[0][0]',
#                                                                      'tf.math.multiply_53[0][0]']
#
#  expanded_conv_14/depthwise  (None, 1, 1, 960)            24000     ['multiply_38[0][0]']
#   (DepthwiseConv2D)
#
#  expanded_conv_14/depthwise  (None, 1, 1, 960)            3840      ['expanded_conv_14/depthwise[0
#  /BatchNorm (BatchNormaliza                                         ][0]']
#  tion)
#
#  tf.__operators__.add_54 (T  (None, 1, 1, 960)            0         ['expanded_conv_14/depthwise/B
#  FOpLambda)                                                         atchNorm[0][0]']
#
#  re_lu_76 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_54[0][0
#                                                                     ]']
#
#  tf.math.multiply_54 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_76[0][0]']
#  ambda)
#
#  multiply_39 (Multiply)      (None, 1, 1, 960)            0         ['expanded_conv_14/depthwise/B
#                                                                     atchNorm[0][0]',
#                                                                      'tf.math.multiply_54[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_39[0][0]']
#  xcite/AvgPool (GlobalAvera
#  gePooling2D)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            230640    ['expanded_conv_14/squeeze_exc
#  xcite/Conv (Conv2D)                                                ite/AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 240)            0         ['expanded_conv_14/squeeze_exc
#  xcite/Relu (ReLU)                                                  ite/Conv[0][0]']
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            231360    ['expanded_conv_14/squeeze_exc
#  xcite/Conv_1 (Conv2D)                                              ite/Relu[0][0]']
#
#  tf.__operators__.add_55 (T  (None, 1, 1, 960)            0         ['expanded_conv_14/squeeze_exc
#  FOpLambda)                                                         ite/Conv_1[0][0]']
#
#  re_lu_77 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_55[0][0
#                                                                     ]']
#
#  tf.math.multiply_55 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_77[0][0]']
#  ambda)
#
#  expanded_conv_14/squeeze_e  (None, 1, 1, 960)            0         ['multiply_39[0][0]',
#  xcite/Mul (Multiply)                                                'tf.math.multiply_55[0][0]']
#
#  expanded_conv_14/project (  (None, 1, 1, 160)            153600    ['expanded_conv_14/squeeze_exc
#  Conv2D)                                                            ite/Mul[0][0]']
#
#  expanded_conv_14/project/B  (None, 1, 1, 160)            640       ['expanded_conv_14/project[0][
#  atchNorm (BatchNormalizati                                         0]']
#  on)
#
#  expanded_conv_14/Add (Add)  (None, 1, 1, 160)            0         ['expanded_conv_13/Add[0][0]',
#                                                                      'expanded_conv_14/project/Bat
#                                                                     chNorm[0][0]']
#
#  Conv_1 (Conv2D)             (None, 1, 1, 960)            153600    ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNor  (None, 1, 1, 960)            3840      ['Conv_1[0][0]']
#  malization)
#
#  tf.__operators__.add_56 (T  (None, 1, 1, 960)            0         ['Conv_1/BatchNorm[0][0]']
#  FOpLambda)
#
#  re_lu_78 (ReLU)             (None, 1, 1, 960)            0         ['tf.__operators__.add_56[0][0
#                                                                     ]']
#
#  tf.math.multiply_56 (TFOpL  (None, 1, 1, 960)            0         ['re_lu_78[0][0]']
#  ambda)
#
#  multiply_40 (Multiply)      (None, 1, 1, 960)            0         ['Conv_1/BatchNorm[0][0]',
#                                                                      'tf.math.multiply_56[0][0]']
#
#  global_average_pooling2d_1  (None, 1, 1, 960)            0         ['multiply_40[0][0]']
#   (GlobalAveragePooling2D)
#
#  Conv_2 (Conv2D)             (None, 1, 1, 1280)           1230080   ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  tf.__operators__.add_57 (T  (None, 1, 1, 1280)           0         ['Conv_2[0][0]']
#  FOpLambda)
#
#  re_lu_79 (ReLU)             (None, 1, 1, 1280)           0         ['tf.__operators__.add_57[0][0
#                                                                     ]']
#
#  tf.math.multiply_57 (TFOpL  (None, 1, 1, 1280)           0         ['re_lu_79[0][0]']
#  ambda)
#
#  multiply_41 (Multiply)      (None, 1, 1, 1280)           0         ['Conv_2[0][0]',
#                                                                      'tf.math.multiply_57[0][0]']
#
#  dropout_1 (Dropout)         (None, 1, 1, 1280)           0         ['multiply_41[0][0]']
#
#  Logits (Conv2D)             (None, 1, 1, 43)             55083     ['dropout_1[0][0]']
#
#  flatten_1 (Flatten)         (None, 43)                   0         ['Logits[0][0]']
#
#  Predictions (Activation)    (None, 43)                   0         ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 4281515 (16.33 MB)
# Trainable params: 4257115 (16.24 MB)
# Non-trainable params: 24400 (95.31 KB)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
print(df["ClassId"].dtype)
df["ClassId"] = df["ClassId"].astype(str)
print(df["ClassId"].dtype)
# Out:
# int64
# object

# %%
df.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  \
# 0     27      26       5       5      22      20
# 1     28      27       5       6      23      22
# 2     29      26       6       5      24      21
# 3     28      27       5       6      23      22
# 4     28      26       5       5      23      21
#
#                              Path  length  height ClassId
# 0  Train/20/00020_00000_00000.png      17      15      20
# 1  Train/20/00020_00000_00001.png      18      16      20
# 2  Train/20/00020_00000_00002.png      18      16      20
# 3  Train/20/00020_00000_00003.png      18      16      20
# 4  Train/20/00020_00000_00004.png      18      16      20

# %%
class Data:
    def __init__(self,df,size_x,size_y):
        self.df = df
        self.root = directory
        self.resize_x = size_x
        self.resize_y = size_y
    
    def resize_and_center(self,image, target_height, target_width):
        original_height, original_width= image.size
        height_ratio = target_height / original_height
        width_ratio = target_width / original_width
        resize_ratio = min(height_ratio, width_ratio)
        new_height = int(original_height * resize_ratio)
        new_width = int(original_width * resize_ratio)
        image  = np.array(image)
        resized_image = cv2.resize(image, (new_width, new_height))
        pad_height = max(0, (target_height - new_height) // 2)
        pad_width = max(0, (target_width - new_width) // 2)
        centered_image = cv2.copyMakeBorder(resized_image, pad_height, target_height - new_height - pad_height,pad_width, target_width - new_width - pad_width,cv2.BORDER_CONSTANT, value=(255, 255, 255))
        return centered_image

    def Do_Crop(self,path,x1,y1,x2,y2):
        img = Image.open(self.root+path)
        img = img.crop((x1,y1,x2,y2))
        img = img.resize((resize_x,resize_y,))
        img = np.array(img,dtype=float)
        img/=255.0
        return img
    
    def Row_Data(self,row):
        self.X.append(self.Do_Crop(row["Path"],row["Roi.X1"],row["Roi.Y1"],row["Roi.X2"],row["Roi.Y2"]))
        self.Y.append(int(row["ClassId"]))
        
    def Get_Data(self):
        self.X = []
        self.Y = []
        for i in range(len(self.df)):
            row = self.df.iloc[i]
            self.Row_Data(row)
        self.X = np.array(self.X)
        self.Y = np.array(self.Y,dtype=int)

# %%
def miniDataTrain(model,df,train_split):
    data = Data(df,resize_x,resize_y)
    data.Get_Data()
    X_train = data.X
    Y_train = data.Y
    history = model.fit(X_train,Y_train,epochs=1,batch_size=len(X_train),validation_split=1-train_split,verbose=0)
    training_accuracy = history.history['accuracy'][0]
    validation_accuracy = history.history['val_accuracy'][0]
    loss = history.history['loss'][0]
    val_loss = history.history['val_loss'][0]
    return [training_accuracy,validation_accuracy,loss,val_loss]    

def SingleEpochTrain(model,df,batchsize=2000,train_split=0.9):
    num_train = len(df)
    num_mini_trains = math.ceil(num_train/batchsize)
    training_accuracy = 0
    validation_accuracy = 0
    loss = 0
    val_loss = 0
    starting_time = time.time()
    for i in range(num_mini_trains):      
        if(num_mini_trains == i+1):
            presentBatchSize = num_train - i*batchsize
        else :
            presentBatchSize = batchsize      
        df1 = df.iloc[i*batchsize:i*batchsize+presentBatchSize,:]
        params = miniDataTrain(model,df1,train_split)
        training_accuracy += presentBatchSize*train_split*params[0]
        validation_accuracy+= presentBatchSize*(1-train_split)*params[1]
        loss += params[2]
        val_loss += params[3]
    training_accuracy/=(num_train*train_split)
    validation_accuracy/=(num_train*(1-train_split))
    
    ending_time = time.time()
    total_time = ending_time - starting_time
    total_time/=60
    print("Accuracy: ",training_accuracy," Val Accuracy: ",validation_accuracy," Trained for ",total_time," min")
    return [training_accuracy,validation_accuracy,loss,val_loss];

# %%
start_time   = time.time()

training_accuracy = []
validation_accuracy = []
loss = []
val_loss = []

for i in range(Epochs):
    print("Epoch : ", i)
    params = SingleEpochTrain(model,df)
    training_accuracy.append(params[0])
    validation_accuracy.append(params[1])
    loss.append(params[2])
    val_loss.append(params[3])

end_time = time.time()
print("Time taken : ", (end_time - start_time)/60," min")
# Out:
# Epoch :  0
# WARNING:tensorflow:From C:\Users\gajul\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\gajul\AppData\Roaming\Python\Python39\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Accuracy:  0.010244042432123377  Val Accuracy:  0.049095607235142114  Trained for  11.730022744337719  min
# Epoch :  1

# %%
#Saving the model
# model.save(filename)

# %%
epochs  = [x for x in range(Epochs)]
plt.figure(figsize=(10,5))
plt.plot(epochs,training_accuracy,color="blue",label="Training Accuracy")
plt.plot(epochs,validation_accuracy,color="red",label="Validation Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
epochs  = [x for x in range(Epochs)]
plt.figure(figsize=(10,5))
plt.plot(epochs,loss,color="blue",label="training loss")
plt.plot(epochs,val_loss,color="red",label="validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
#  ***Test Image Classification and Accuracy Calculation***

# %%
#Loading weights into CNN model 
# model = tf.keras.models.load_model("CNN_SimpleLayered")

# %%
df_test = pd.read_csv(testdir)
df_test["ClassId"] =df_test["ClassId"].astype(str)
print("Number of Test Images are ", len(df_test))
df_test.dropna()
df_test.head()

# %%
viewStatistics(df_test)

# %%
df_test.head()

# %%
showTestExamples(df_test)

# %%
X = df_test.drop(Y_col_name, axis=1)
y = df_test[Y_col_name]
oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)

# Fit and apply the oversampler to the data
X_resampled, y_resampled = oversampler.fit_resample(X, y)

df_test = pd.DataFrame(X_resampled, columns=X.columns)
df_test[Y_col_name] = y_resampled
df_test[Y_col_name] = df_test[Y_col_name].astype(str)

# %%
df_test.head()

# %%
test_images = []
data = Data(df_test,resize_x,resize_y)
data.Get_Data()
X_test  = data.X
y_test = data.Y
X_test/=255.0

# %%
pred = model.predict(X_test)
y_pred = np.argmax(pred, axis=1)

# %%
confusion = confusion_matrix(y_test, y_pred)

# Calculate accuracy
accuracy = np.sum(np.diag(confusion)) / np.sum(confusion)
print("Total Accuracy: ", accuracy*100)

# Calculate precision, recall, and F1-score
classification_rep = classification_report(y_test, y_pred, labels=np.unique(y_pred))

# Print the results
print("\nConfusion Matrix:\n", confusion)


lines = classification_rep.split('\n')
data = []

for line in lines[2:-5]:  # Exclude header and footer lines
    row_data = line.split()
    if len(row_data) > 0:
        class_name = row_data[0]
        precision = float(row_data[1])
        recall = float(row_data[2])
        f1_score = float(row_data[3])
        support = int(row_data[4])
        data.append([class_name, precision, recall, f1_score, support])

# Create a DataFrame
report = pd.DataFrame(data, columns=['Class', 'Precision', 'Recall', 'F1-Score', 'Support'])
# Print the DataFrame
print("\n\n\n Summarizing the results : ")
report

# %%
class_names = []
for i in range(num_of_classes):
    class_names.append("Class "+str(i))
# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion, annot=False, cmap="viridis", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
